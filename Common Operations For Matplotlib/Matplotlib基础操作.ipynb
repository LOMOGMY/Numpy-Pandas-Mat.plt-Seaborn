# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline #在notebook中使用，即可不用调用show就直接展示图片

# %% [markdown]
# ## 最基本的图

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.xlabel('xlabel',fontsize = 16)
plt.ylabel('ylabel')
# Out:
# Text(0,0.5,'ylabel')

# %% [markdown]
# ### 不同的线条

# %% [markdown]
# 字符|类型 | 字符|类型
# ---|--- | --- | ---
# `  '-'	`| 实线 | `'--'`|	虚线
# `'-.'`|	虚点线 | `':'`|	点线
# `'.'`|	点 | `','`| 像素点
# `'o'`	|圆点 | `'v'`|	下三角点
# `'^'`|	上三角点 | `'<'`|	左三角点
# `'>'`|	右三角点 | `'1'`|	下三叉点
# `'2'`|	上三叉点 | `'3'`|	左三叉点
# `'4'`|	右三叉点 | `'s'`|	正方点
# `'p'`	| 五角点 | `'*'`|	星形点
# `'h'`|	六边形点1 | `'H'`|	六边形点2
# `'+'`|	加号点 | `'x'`|	乘号点
# `'D'`|	实心菱形点 | `'d'`|	瘦菱形点
# `'_'`|	横线点 | |

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],':')
plt.xlabel('xlabel',fontsize = 16)
plt.ylabel('ylabel')
# Out:
# Text(0,0.5,'ylabel')

# %% [markdown]
# ### 颜色

# %% [markdown]
# 颜色
# 表示颜色的字符参数有：
#
# 字符 | 颜色
# -- | --
# `‘b’`|	蓝色，blue
# `‘g’`|	绿色，green
# `‘r’`|	红色，red
# `‘c’`|	青色，cyan
# `‘m’`|	品红，magenta
# `‘y’`|	黄色，yellow
# `‘k’`|	黑色，black
# `‘w’`|	白色，white

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],':',color = 'r')
plt.xlabel('xlabel',fontsize = 16)
plt.ylabel('ylabel')
# Out:
# Text(0,0.5,'ylabel')

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'ro')  #'ro'将线条类型和颜色整合到一起
plt.xlabel('xlabel',fontsize = 16)
plt.ylabel('ylabel')
# Out:
# Text(0,0.5,'ylabel')

# %% [markdown]
# ### 多个线条

# %%
numpy = np.arange(0,10,0.5)
plt.plot(numpy,numpy,'r--')
plt.plot(numpy,numpy**2,'bs')
plt.plot(numpy,numpy**3,'go')

# %%
# 第二种方法，一张图中画多条线
plt.plot(numpy,numpy,'r--',
        numpy,numpy**2,'bs',
        numpy,numpy**3,'go')
# Out:
# [<matplotlib.lines.Line2D at 0x196a030b8d0>,
#  <matplotlib.lines.Line2D at 0x196a030ba58>,
#  <matplotlib.lines.Line2D at 0x196a030f2b0>]

# %%
x = np.linspace(-10,10)
y = np.sin(x)
plt.plot(x,y,linewidth = 2.0)  #linewidth指定线条宽度

# %% [markdown]
# #### plt.plot(x,y,color = ,linestyle = ,marker = ,markerfacecolor = ,markersize = )

# %%
plt.figure(figsize=(8,6))
plt.plot(x,y,color = 'b',linestyle = ':',marker = 'o',markerfacecolor = 'r',markersize = 10)
#marker就是标志点即np.linspace(-10,10)这些值,markersize即指定这些点的大小

# %% [markdown]
# #### 也可以先把图画出来再用 plt.setp()设置参数

# %%
line = plt.plot(x,y)
plt.setp(line,color='r',linewidth = 2.0, alpha = 0.1) #alpha即透明程度
# Out:
# [None, None, None]

# %% [markdown]
# ## 子图

# %%
plt.figure(figsize=(8,6))
# 211 表示一会要画的图是2行一列的 最后一个1表示的是子图当中的第1个图
plt.subplot(211)
plt.plot(x,y,color='r')

# 212 表示一会要画的图是2行一列的 最后一个1表示的是子图当中的第2个图
plt.subplot(212)
plt.plot(x,y,color='b')

# %%
plt.figure(figsize=(12,6))
# 211 表示一会要画的图是1行2列的 最后一个1表示的是子图当中的第1个图
plt.subplot(121)
plt.plot(x,y,color='r')

# 212 表示一会要画的图是1行2列的 最后一个1表示的是子图当中的第2个图
plt.subplot(122)
plt.plot(x,y,color='b')

# %% [markdown]
# ## 给图加注释
# * plt.annotate()

# %%
plt.figure(figsize=(8,6))
plt.plot(x,y,color='b',linestyle=':',marker = 'o',markerfacecolor='r',markersize = 10)
plt.xlabel('x:---')
plt.ylabel('y:---')
plt.title('Title here:---')
plt.text(0,0,'example')
plt.grid(True)
plt.annotate('LOMO',xy=(-5,0),xytext=(-2,0.3),arrowprops = dict(facecolor='red',
                                                                shrink=0.05,headlength= 20,headwidth = 20))
#xy为箭头指向的位置 ，xytext为标注文本的位置（箭头的尾部也在这里），dict中shrink是箭头缩短的长度(0为不缩短，
#1为缩到最短)
# Out:
# Text(-2,0.3,'LOMO')
